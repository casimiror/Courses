# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 100
np.random.seed(seed=1)
X = np.random.random(N)*10 - 5

Y = 0.5 * X - 1 + np.random.randn(N)

# %%
plt.scatter(X, Y)

# %%
model = nn.Linear(1, 1)

criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %%
X = X.reshape(N, 1)
Y = Y.reshape(N, 1)

# %%
inputs = torch.from_numpy(X.astype(np.float32))
targets = torch.from_numpy(Y.astype(np.float32))

type(inputs)
# Out:
# torch.Tensor

# %%
n_epochs = 30
losses = []
for epoch in range(n_epochs):
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    
    losses.append(loss.item())
    loss.backward()
    optimizer.step()
    print(f"Epoch {epoch}/{n_epochs}, Loss: {loss.item():.4f}")
# Out:
# Epoch 0/30, Loss: 1.0644
# Epoch 1/30, Loss: 1.0539
# Epoch 2/30, Loss: 1.0438
# Epoch 3/30, Loss: 1.0341
# Epoch 4/30, Loss: 1.0249
# Epoch 5/30, Loss: 1.0160
# Epoch 6/30, Loss: 1.0074
# Epoch 7/30, Loss: 0.9992
# Epoch 8/30, Loss: 0.9913
# Epoch 9/30, Loss: 0.9837
# Epoch 10/30, Loss: 0.9765
# Epoch 11/30, Loss: 0.9695
# Epoch 12/30, Loss: 0.9628
# Epoch 13/30, Loss: 0.9564
# Epoch 14/30, Loss: 0.9502
# Epoch 15/30, Loss: 0.9442
# Epoch 16/30, Loss: 0.9385
# Epoch 17/30, Loss: 0.9330
# Epoch 18/30, Loss: 0.9278
# Epoch 19/30, Loss: 0.9227
# Epoch 20/30, Loss: 0.9179
# Epoch 21/30, Loss: 0.9132
# Epoch 22/30, Loss: 0.9087
# Epoch 23/30, Loss: 0.9044
# Epoch 24/30, Loss: 0.9003
# Epoch 25/30, Loss: 0.8963
# Epoch 26/30, Loss: 0.8925
# Epoch 27/30, Loss: 0.8888
# Epoch 28/30, Loss: 0.8853
# Epoch 29/30, Loss: 0.8819

# %%
plt.plot(losses)

# %%
predicted = model(inputs).detach().numpy()
plt.scatter(X,Y, label='Original data')
plt.plot(X, predicted, label='Fitted line')
plt.legend()
plt.show()

# %%
model.parameters()
# Out:
# <generator object Module.parameters at 0x7fd2a3f43a00>

# %%
for param in model.parameters():
    print(param)
# Out:
# Parameter containing:
# tensor([[0.4736]], requires_grad=True)
# Parameter containing:
# tensor([-0.6393], requires_grad=True)
